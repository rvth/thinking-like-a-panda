# %%
import pandas as pd
import re

# %%
dogs = pd.read_csv(r'Downloads/ShelterDogs.csv')

# %%
dogs.head()
# Out:
#       ID            name   age     sex               breed  date_found  \
# 0  23807            Gida  0.25  female         Unknown Mix  2019-12-10
# 1    533  Frida És Ricsi  0.17  female         Unknown Mix  2019-12-01
# 2  23793             NaN  4.00    male         Unknown Mix  2019-12-08
# 3  23795             NaN  1.00    male         Unknown Mix  2019-12-08
# 4  23806             Amy  2.00  female  French Bulldog Mix  2019-12-10
#
#   adoptable_from      posted            color    coat    size neutered  \
# 0     2019-12-11  2019-12-11              red   short   small       no
# 1     2019-12-01  2019-12-09  black and white   short   small       no
# 2     2019-12-23  2019-12-08      saddle back   short  medium       no
# 3     2019-12-23  2019-12-08     yellow-brown  medium  medium       no
# 4     2019-12-11  2019-12-11            black   short   small       no
#
#   housebroken likes_people likes_children get_along_males get_along_females  \
# 0         NaN          NaN            NaN             NaN               NaN
# 1         NaN          yes            yes             yes               yes
# 2         NaN          NaN            NaN             NaN               NaN
# 3         NaN          NaN            NaN             NaN               NaN
# 4         NaN          NaN            NaN             NaN               NaN
#
#   get_along_cats keep_in
# 0            NaN     NaN
# 1            yes     NaN
# 2            NaN     NaN
# 3            NaN     NaN
# 4            NaN     NaN

# %%
dogs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2937 entries, 0 to 2936
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID                 2937 non-null   int64
#  1   name               2845 non-null   object
#  2   age                2937 non-null   float64
#  3   sex                2937 non-null   object
#  4   breed              2937 non-null   object
#  5   date_found         2937 non-null   object
#  6   adoptable_from     2937 non-null   object
#  7   posted             2937 non-null   object
#  8   color              2937 non-null   object
#  9   coat               2937 non-null   object
#  10  size               2937 non-null   object
#  11  neutered           1852 non-null   object
#  12  housebroken        460 non-null    object
#  13  likes_people       1999 non-null   object
#  14  likes_children     1219 non-null   object
#  15  get_along_males    1633 non-null   object
#  16  get_along_females  1673 non-null   object
#  17  get_along_cats     431 non-null    object
#  18  keep_in            1916 non-null   object
# dtypes: float64(1), int64(1), object(17)
# memory usage: 436.1+ KB

# %%
dogs['date_found'] = pd.to_datetime(dogs['date_found'])
dogs
# Out:
#          ID            name    age     sex                           breed  \
# 0     23807            Gida   0.25  female                     Unknown Mix
# 1       533  Frida És Ricsi   0.17  female                     Unknown Mix
# 2     23793             NaN   4.00    male                     Unknown Mix
# 3     23795             NaN   1.00    male                     Unknown Mix
# 4     23806             Amy   2.00  female              French Bulldog Mix
# ...     ...             ...    ...     ...                             ...
# 2932    118           Fodri  16.92    male                     Unknown Mix
# 2933    262           Csibi  17.33  female       Staffordshire Terrier Mix
# 2934      4          Konrád  18.17    male                     Unknown Mix
# 2935    141           Kölni  17.17    male                     Unknown Mix
# 2936    248          Kedves  16.08    male  German Shepherd Dog, Hound Mix
#
#      date_found adoptable_from      posted            color    coat    size  \
# 0    2019-12-10     2019-12-11  2019-12-11              red   short   small
# 1    2019-12-01     2019-12-01  2019-12-09  black and white   short   small
# 2    2019-12-08     2019-12-23  2019-12-08      saddle back   short  medium
# 3    2019-12-08     2019-12-23  2019-12-08     yellow-brown  medium  medium
# 4    2019-12-10     2019-12-11  2019-12-11            black   short   small
# ...         ...            ...         ...              ...     ...     ...
# 2932 2003-12-25     2003-12-25  2006-03-22     yellow-brown   short  medium
# 2933 2004-08-27     2004-08-27  2005-07-08          striped   short   large
# 2934 2005-09-21     2005-09-21  2005-10-26            black   short  medium
# 2935 2004-11-27     2004-11-27  2005-05-02  black and brown  medium  medium
# 2936 2005-04-02     2005-04-02  2005-06-30            sable   short  medium
#
#      neutered housebroken likes_people likes_children get_along_males  \
# 0          no         NaN          NaN            NaN             NaN
# 1          no         NaN          yes            yes             yes
# 2          no         NaN          NaN            NaN             NaN
# 3          no         NaN          NaN            NaN             NaN
# 4          no         NaN          NaN            NaN             NaN
# ...       ...         ...          ...            ...             ...
# 2932       no          no          yes            yes              no
# 2933      yes         NaN          NaN            NaN             NaN
# 2934       no         NaN          NaN            NaN             NaN
# 2935       no         NaN          NaN            NaN             NaN
# 2936      yes         NaN          yes            NaN             yes
#
#      get_along_females get_along_cats               keep_in
# 0                  NaN            NaN                   NaN
# 1                  yes            yes                   NaN
# 2                  NaN            NaN                   NaN
# 3                  NaN            NaN                   NaN
# 4                  NaN            NaN                   NaN
# ...                ...            ...                   ...
# 2932               yes             no                garden
# 2933               NaN            NaN                   NaN
# 2934               NaN            NaN                   NaN
# 2935               NaN            NaN                   NaN
# 2936               yes            NaN  both flat and garden
#
# [2937 rows x 19 columns]

# %%
dogs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2937 entries, 0 to 2936
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID                 2937 non-null   int64
#  1   name               2845 non-null   object
#  2   age                2937 non-null   float64
#  3   sex                2937 non-null   object
#  4   dog_breed          2937 non-null   object
#  5   date_found         2937 non-null   datetime64[ns]
#  6   date_adoptable     2937 non-null   datetime64[ns]
#  7   date_posted        2937 non-null   datetime64[ns]
#  8   color              2937 non-null   object
#  9   coat_type          2937 non-null   object
#  10  size               2937 non-null   object
#  11  neutered           1852 non-null   object
#  12  housebroken        460 non-null    object
#  13  likes_people       1999 non-null   object
#  14  likes_children     1219 non-null   object
#  15  get_along_males    1633 non-null   object
#  16  get_along_females  1673 non-null   object
#  17  get_along_cats     431 non-null    object
#  18  keep_in            1916 non-null   object
# dtypes: datetime64[ns](3), float64(1), int64(1), object(14)
# memory usage: 436.1+ KB

# %%
dogs.shape
# Out:
# (2937, 19)

# %%
name = dogs.name
print(name.head())
# Out:
# 0              Gida
# 1    Frida És Ricsi
# 2               NaN
# 3               NaN
# 4               Amy
# Name: name, dtype: object

# %%
type_breed = dogs[['name', 'sex', 'breed']]
type_breed.head()
# Out:
#              name     sex               breed
# 0            Gida  female         Unknown Mix
# 1  Frida És Ricsi  female         Unknown Mix
# 2             NaN    male         Unknown Mix
# 3             NaN    male         Unknown Mix
# 4             Amy  female  French Bulldog Mix

# %%
dogs.iloc[1]
# Out:
# ID                               533
# name                  Frida És Ricsi
# age                             0.17
# sex                           female
# breed                    Unknown Mix
# date_found                2019-12-01
# adoptable_from            2019-12-01
# posted                    2019-12-09
# color                black and white
# coat                           short
# size                           small
# neutered                          no
# housebroken                      NaN
# likes_people                     yes
# likes_children                   yes
# get_along_males                  yes
# get_along_females                yes
# get_along_cats                   yes
# keep_in                          NaN
# Name: 1, dtype: object

# %%
dogs.iloc[3:7]
# Out:
#       ID            name   age     sex               breed  date_found  \
# 3  23795             NaN  1.00    male         Unknown Mix  2019-12-08
# 4  23806             Amy  2.00  female  French Bulldog Mix  2019-12-10
# 5  23801            Alex  4.25    male         Unknown Mix  2019-12-09
# 6    534  Ricsi És Frida  0.17    male         Unknown Mix  2019-12-01
#
#   adoptable_from      posted         color    coat    size neutered  \
# 3     2019-12-23  2019-12-08  yellow-brown  medium  medium       no
# 4     2019-12-11  2019-12-11         black   short   small       no
# 5     2019-12-24  2019-12-09  yellow-brown   short   small      yes
# 6     2019-12-01  2019-12-09         brown   short   small       no
#
#   housebroken likes_people likes_children get_along_males get_along_females  \
# 3         NaN          NaN            NaN             NaN               NaN
# 4         NaN          NaN            NaN             NaN               NaN
# 5         NaN          NaN            NaN             NaN               NaN
# 6         NaN          yes            yes             yes               yes
#
#   get_along_cats keep_in
# 3            NaN     NaN
# 4            NaN     NaN
# 5            NaN     NaN
# 6            yes     NaN

# %%
dogs.iloc[:10]
# Out:
#       ID              name   age     sex               breed  date_found  \
# 0  23807              Gida  0.25  female         Unknown Mix  2019-12-10
# 1    533    Frida És Ricsi  0.17  female         Unknown Mix  2019-12-01
# 2  23793               NaN  4.00    male         Unknown Mix  2019-12-08
# 3  23795               NaN  1.00    male         Unknown Mix  2019-12-08
# 4  23806               Amy  2.00  female  French Bulldog Mix  2019-12-10
# 5  23801              Alex  4.25    male         Unknown Mix  2019-12-09
# 6    534    Ricsi És Frida  0.17    male         Unknown Mix  2019-12-01
# 7  23805               NaN  0.17  female         Unknown Mix  2019-12-10
# 8  23809               NaN  0.17  female         Unknown Mix  2019-12-11
# 9   1801  Újhartyáni Mazsi  0.17  female         Unknown Mix  2019-12-10
#
#   adoptable_from      posted            color    coat    size neutered  \
# 0     2019-12-11  2019-12-11              red   short   small       no
# 1     2019-12-01  2019-12-09  black and white   short   small       no
# 2     2019-12-23  2019-12-08      saddle back   short  medium       no
# 3     2019-12-23  2019-12-08     yellow-brown  medium  medium       no
# 4     2019-12-11  2019-12-11            black   short   small       no
# 5     2019-12-24  2019-12-09     yellow-brown   short   small      yes
# 6     2019-12-01  2019-12-09            brown   short   small       no
# 7     2019-12-25  2019-12-11   gray and white   short  medium       no
# 8     2019-12-26  2019-12-12            black  medium  medium       no
# 9     2019-12-10  2019-12-11  brown and white   short   small       no
#
#   housebroken likes_people likes_children get_along_males get_along_females  \
# 0         NaN          NaN            NaN             NaN               NaN
# 1         NaN          yes            yes             yes               yes
# 2         NaN          NaN            NaN             NaN               NaN
# 3         NaN          NaN            NaN             NaN               NaN
# 4         NaN          NaN            NaN             NaN               NaN
# 5         NaN          NaN            NaN             NaN               NaN
# 6         NaN          yes            yes             yes               yes
# 7         NaN          NaN            NaN             NaN               NaN
# 8         NaN          NaN            NaN             NaN               NaN
# 9         NaN          yes            yes             yes               yes
#
#   get_along_cats keep_in
# 0            NaN     NaN
# 1            yes     NaN
# 2            NaN     NaN
# 3            NaN     NaN
# 4            NaN     NaN
# 5            NaN     NaN
# 6            yes     NaN
# 7            NaN     NaN
# 8            NaN     NaN
# 9            yes    flat

# %%
dogs.iloc[-2:]
# Out:
#        ID    name    age   sex                           breed  date_found  \
# 2935  141   Kölni  17.17  male                     Unknown Mix  2004-11-27
# 2936  248  Kedves  16.08  male  German Shepherd Dog, Hound Mix  2005-04-02
#
#      adoptable_from      posted            color    coat    size neutered  \
# 2935     2004-11-27  2005-05-02  black and brown  medium  medium       no
# 2936     2005-04-02  2005-06-30            sable   short  medium      yes
#
#      housebroken likes_people likes_children get_along_males  \
# 2935         NaN          NaN            NaN             NaN
# 2936         NaN          yes            NaN             yes
#
#      get_along_females get_along_cats               keep_in
# 2935               NaN            NaN                   NaN
# 2936               yes            NaN  both flat and garden

# %%
dogs.rename(columns = {'posted' : 'date_posted', 
                         'breed' : 'dog_breed',
                         'adoptable_from' : 'date_adoptable',
                         'coat' : 'coat_type'},
                         inplace = True)

# %%
dogs.head()
# Out:
#       ID            name   age     sex           dog_breed  date_found  \
# 0  23807            Gida  0.25  female         Unknown Mix  2019-12-10
# 1    533  Frida És Ricsi  0.17  female         Unknown Mix  2019-12-01
# 2  23793             NaN  4.00    male         Unknown Mix  2019-12-08
# 3  23795             NaN  1.00    male         Unknown Mix  2019-12-08
# 4  23806             Amy  2.00  female  French Bulldog Mix  2019-12-10
#
#   date_adoptable date_posted            color coat_type    size neutered  \
# 0     2019-12-11  2019-12-11              red     short   small       no
# 1     2019-12-01  2019-12-09  black and white     short   small       no
# 2     2019-12-23  2019-12-08      saddle back     short  medium       no
# 3     2019-12-23  2019-12-08     yellow-brown    medium  medium       no
# 4     2019-12-11  2019-12-11            black     short   small       no
#
#   housebroken likes_people likes_children get_along_males get_along_females  \
# 0         NaN          NaN            NaN             NaN               NaN
# 1         NaN          yes            yes             yes               yes
# 2         NaN          NaN            NaN             NaN               NaN
# 3         NaN          NaN            NaN             NaN               NaN
# 4         NaN          NaN            NaN             NaN               NaN
#
#   get_along_cats keep_in
# 0            NaN     NaN
# 1            yes     NaN
# 2            NaN     NaN
# 3            NaN     NaN
# 4            NaN     NaN

# %%
female = dogs[dogs.sex == 'female']
female
# Out:
#          ID            name    age     sex  \
# 0     23807            Gida   0.25  female
# 1       533  Frida És Ricsi   0.17  female
# 4     23806             Amy   2.00  female
# 7     23805             NaN   0.17  female
# 8     23809             NaN   0.17  female
# ...     ...             ...    ...     ...
# 2923    356         Barbara  13.75  female
# 2926    109            Kari  13.33  female
# 2930    389           Pötyi  14.25  female
# 2931    362          Tündér  14.75  female
# 2933    262           Csibi  17.33  female
#
#                                    dog_breed  date_found date_adoptable  \
# 0                                Unknown Mix  2019-12-10     2019-12-11
# 1                                Unknown Mix  2019-12-01     2019-12-01
# 4                         French Bulldog Mix  2019-12-10     2019-12-11
# 7                                Unknown Mix  2019-12-10     2019-12-25
# 8                                Unknown Mix  2019-12-11     2019-12-26
# ...                                      ...         ...            ...
# 2923                             Unknown Mix  2006-06-01     2006-06-01
# 2926             German Pointer, Pointer Mix  2007-01-15     2007-01-15
# 2930  German Pointer, Greyhound, Pointer Mix  2006-08-01     2006-08-01
# 2931                  Labrador Retriever Mix  2006-05-01     2006-05-01
# 2933               Staffordshire Terrier Mix  2004-08-27     2004-08-27
#
#      date_posted            color coat_type    size neutered housebroken  \
# 0     2019-12-11              red     short   small       no         NaN
# 1     2019-12-09  black and white     short   small       no         NaN
# 4     2019-12-11            black     short   small       no         NaN
# 7     2019-12-11   gray and white     short  medium       no         NaN
# 8     2019-12-12            black    medium  medium       no         NaN
# ...          ...              ...       ...     ...      ...         ...
# 2923  2006-06-28  black and brown     short  medium       no         NaN
# 2926  2007-03-16  black and white     short  medium      NaN         NaN
# 2930  2006-08-20  black and white     short  medium      yes         NaN
# 2931  2006-06-28          apricot    medium  medium      yes         NaN
# 2933  2005-07-08          striped     short   large      yes         NaN
#
#      likes_people likes_children get_along_males get_along_females  \
# 0             NaN            NaN             NaN               NaN
# 1             yes            yes             yes               yes
# 4             NaN            NaN             NaN               NaN
# 7             NaN            NaN             NaN               NaN
# 8             NaN            NaN             NaN               NaN
# ...           ...            ...             ...               ...
# 2923          NaN            yes             yes               yes
# 2926          NaN            NaN             NaN               NaN
# 2930          NaN            NaN             NaN               NaN
# 2931          NaN            yes             yes               yes
# 2933          NaN            NaN             NaN               NaN
#
#      get_along_cats               keep_in
# 0               NaN                   NaN
# 1               yes                   NaN
# 4               NaN                   NaN
# 7               NaN                   NaN
# 8               NaN                   NaN
# ...             ...                   ...
# 2923            NaN  both flat and garden
# 2926            NaN                   NaN
# 2930            NaN  both flat and garden
# 2931            NaN  both flat and garden
# 2933            NaN                   NaN
#
# [1256 rows x 19 columns]

# %%
breeds = dogs[dogs.dog_breed != 'Unknown Mix']
breeds
# Out:
#          ID     name    age     sex                               dog_breed  \
# 4     23806      Amy   2.00  female                      French Bulldog Mix
# 10     1222     Vasi   3.67    male                              Vizsla Mix
# 14      532    Fickó   1.50    male             Bull Terrier, Dachshund Mix
# 20    23788     Sába   7.58  female                                  Kuvasz
# 25     4491  Bethany   5.00  female                    Chinese Shar-Pei Mix
# ...     ...      ...    ...     ...                                     ...
# 2928    110   Kavics  13.75    male                                Pumi Mix
# 2930    389    Pötyi  14.25  female  German Pointer, Greyhound, Pointer Mix
# 2931    362   Tündér  14.75  female                  Labrador Retriever Mix
# 2933    262    Csibi  17.33  female               Staffordshire Terrier Mix
# 2936    248   Kedves  16.08    male          German Shepherd Dog, Hound Mix
#
#       date_found date_adoptable date_posted            color coat_type  \
# 4     2019-12-10     2019-12-11  2019-12-11            black     short
# 10    2019-10-25     2019-10-25  2019-12-12              red     short
# 14    2019-12-01     2019-12-01  2019-12-09  brown and white     short
# 20    2019-12-01     2019-12-16  2019-12-08            white    medium
# 25    2019-11-28     2019-11-28  2019-12-07  black and brown     short
# ...          ...            ...         ...              ...       ...
# 2928  2007-01-15     2007-01-15  2007-03-17          striped    medium
# 2930  2006-08-01     2006-08-01  2006-08-20  black and white     short
# 2931  2006-05-01     2006-05-01  2006-06-28          apricot    medium
# 2933  2004-08-27     2004-08-27  2005-07-08          striped     short
# 2936  2005-04-02     2005-04-02  2005-06-30            sable     short
#
#         size neutered housebroken likes_people likes_children get_along_males  \
# 4      small       no         NaN          NaN            NaN             NaN
# 10    medium      yes         NaN          NaN            NaN             NaN
# 14    medium      yes         NaN          yes            yes              no
# 20     large      yes         NaN          NaN            NaN             NaN
# 25    medium      NaN         NaN          yes            NaN             NaN
# ...      ...      ...         ...          ...            ...             ...
# 2928  medium      NaN         NaN          yes            yes             yes
# 2930  medium      yes         NaN          NaN            NaN             NaN
# 2931  medium      yes         NaN          NaN            yes             yes
# 2933   large      yes         NaN          NaN            NaN             NaN
# 2936  medium      yes         NaN          yes            NaN             yes
#
#      get_along_females get_along_cats               keep_in
# 4                  NaN            NaN                   NaN
# 10                 NaN            NaN                   NaN
# 14                  no             no                   NaN
# 20                 NaN            NaN                   NaN
# 25                 NaN            NaN  both flat and garden
# ...                ...            ...                   ...
# 2928               yes            NaN  both flat and garden
# 2930               NaN            NaN  both flat and garden
# 2931               yes            NaN  both flat and garden
# 2933               NaN            NaN                   NaN
# 2936               yes            NaN  both flat and garden
#
# [1413 rows x 19 columns]

# %%
over_two = dogs[dogs.age > 2]
over_two
# Out:
#          ID    name    age     sex                       dog_breed  \
# 2     23793     NaN   4.00    male                     Unknown Mix
# 5     23801    Alex   4.25    male                     Unknown Mix
# 10     1222    Vasi   3.67    male                      Vizsla Mix
# 12    23797     NaN   5.00  female                     Unknown Mix
# 15    23796     NaN   8.00    male                     Unknown Mix
# ...     ...     ...    ...     ...                             ...
# 2932    118   Fodri  16.92    male                     Unknown Mix
# 2933    262   Csibi  17.33  female       Staffordshire Terrier Mix
# 2934      4  Konrád  18.17    male                     Unknown Mix
# 2935    141   Kölni  17.17    male                     Unknown Mix
# 2936    248  Kedves  16.08    male  German Shepherd Dog, Hound Mix
#
#       date_found date_adoptable date_posted            color coat_type  \
# 2     2019-12-08     2019-12-23  2019-12-08      saddle back     short
# 5     2019-12-09     2019-12-24  2019-12-09     yellow-brown     short
# 10    2019-10-25     2019-10-25  2019-12-12              red     short
# 12    2019-12-08     2019-12-23  2019-12-08            brown      long
# 15    2019-12-08     2019-12-23  2019-12-08            black    medium
# ...          ...            ...         ...              ...       ...
# 2932  2003-12-25     2003-12-25  2006-03-22     yellow-brown     short
# 2933  2004-08-27     2004-08-27  2005-07-08          striped     short
# 2934  2005-09-21     2005-09-21  2005-10-26            black     short
# 2935  2004-11-27     2004-11-27  2005-05-02  black and brown    medium
# 2936  2005-04-02     2005-04-02  2005-06-30            sable     short
#
#         size neutered housebroken likes_people likes_children get_along_males  \
# 2     medium       no         NaN          NaN            NaN             NaN
# 5      small      yes         NaN          NaN            NaN             NaN
# 10    medium      yes         NaN          NaN            NaN             NaN
# 12     small       no         NaN          NaN            NaN             NaN
# 15    medium       no         NaN          NaN            NaN             NaN
# ...      ...      ...         ...          ...            ...             ...
# 2932  medium       no          no          yes            yes              no
# 2933   large      yes         NaN          NaN            NaN             NaN
# 2934  medium       no         NaN          NaN            NaN             NaN
# 2935  medium       no         NaN          NaN            NaN             NaN
# 2936  medium      yes         NaN          yes            NaN             yes
#
#      get_along_females get_along_cats               keep_in
# 2                  NaN            NaN                   NaN
# 5                  NaN            NaN                   NaN
# 10                 NaN            NaN                   NaN
# 12                 NaN            NaN                   NaN
# 15                 NaN            NaN                   NaN
# ...                ...            ...                   ...
# 2932               yes             no                garden
# 2933               NaN            NaN                   NaN
# 2934               NaN            NaN                   NaN
# 2935               NaN            NaN                   NaN
# 2936               yes            NaN  both flat and garden
#
# [2711 rows x 19 columns]

# %%
four_and_under = dogs[dogs.age < 4]
four_and_under
# Out:
#         ID            name   age     sex           dog_breed  date_found  \
# 0    23807            Gida  0.25  female         Unknown Mix  2019-12-10
# 1      533  Frida És Ricsi  0.17  female         Unknown Mix  2019-12-01
# 3    23795             NaN  1.00    male         Unknown Mix  2019-12-08
# 4    23806             Amy  2.00  female  French Bulldog Mix  2019-12-10
# 6      534  Ricsi És Frida  0.17    male         Unknown Mix  2019-12-01
# ..     ...             ...   ...     ...                 ...         ...
# 906   1445           Gixer  3.92    male         Unknown Mix  2016-01-19
# 910   1441           Gréta  3.92  female         Unknown Mix  2016-01-19
# 911   1442           Garbó  3.92    male         Unknown Mix  2016-01-19
# 912   1448           Gamma  3.92  female         Unknown Mix  2016-01-19
# 917   1444          Glenda  3.92  female         Unknown Mix  2016-01-19
#
#     date_adoptable date_posted            color coat_type    size neutered  \
# 0       2019-12-11  2019-12-11              red     short   small       no
# 1       2019-12-01  2019-12-09  black and white     short   small       no
# 3       2019-12-23  2019-12-08     yellow-brown    medium  medium       no
# 4       2019-12-11  2019-12-11            black     short   small       no
# 6       2019-12-01  2019-12-09            brown     short   small       no
# ..             ...         ...              ...       ...     ...      ...
# 906     2016-01-19  2016-03-15      saddle back     short  medium      NaN
# 910     2016-01-19  2016-03-15  black and brown    medium  medium      NaN
# 911     2016-01-19  2016-03-15            brown      long  medium      NaN
# 912     2016-01-19  2016-03-15            brown     short  medium      NaN
# 917     2016-01-19  2016-03-15            black     short  medium      NaN
#
#     housebroken likes_people likes_children get_along_males get_along_females  \
# 0           NaN          NaN            NaN             NaN               NaN
# 1           NaN          yes            yes             yes               yes
# 3           NaN          NaN            NaN             NaN               NaN
# 4           NaN          NaN            NaN             NaN               NaN
# 6           NaN          yes            yes             yes               yes
# ..          ...          ...            ...             ...               ...
# 906         NaN          NaN            NaN             NaN               NaN
# 910         NaN          NaN            NaN             NaN               NaN
# 911         NaN          NaN            NaN             NaN               NaN
# 912         NaN          NaN            NaN             NaN               NaN
# 917         NaN          NaN            NaN             NaN               NaN
#
#     get_along_cats keep_in
# 0              NaN     NaN
# 1              yes     NaN
# 3              NaN     NaN
# 4              NaN     NaN
# 6              yes     NaN
# ..             ...     ...
# 906            NaN     NaN
# 910            NaN     NaN
# 911            NaN     NaN
# 912            NaN     NaN
# 917            NaN     NaN
#
# [443 rows x 19 columns]

# %%
likes_people = dogs[(dogs.likes_people == 'yes') & (dogs.likes_children == 'yes')]
likes_people
# Out:
#         ID               name    age     sex                    dog_breed  \
# 1      533     Frida És Ricsi   0.17  female                  Unknown Mix
# 6      534     Ricsi És Frida   0.17    male                  Unknown Mix
# 9     1801   Újhartyáni Mazsi   0.17  female                  Unknown Mix
# 13    1800  Újhartyáni Frenki   0.17    male                  Unknown Mix
# 14     532              Fickó   1.50    male  Bull Terrier, Dachshund Mix
# ...    ...                ...    ...     ...                          ...
# 2918     6               Fifi  13.67  female      German Shepherd Dog Mix
# 2919    12              Kitty  15.67  female                       Kuvasz
# 2925   427               Yuki  13.75    male      German Shepherd Dog Mix
# 2928   110             Kavics  13.75    male                     Pumi Mix
# 2932   118              Fodri  16.92    male                  Unknown Mix
#
#       date_found date_adoptable date_posted            color coat_type  \
# 1     2019-12-01     2019-12-01  2019-12-09  black and white     short
# 6     2019-12-01     2019-12-01  2019-12-09            brown     short
# 9     2019-12-10     2019-12-10  2019-12-11  brown and white     short
# 13    2019-12-10     2019-12-10  2019-12-11         tricolor     short
# 14    2019-12-01     2019-12-01  2019-12-09  brown and white     short
# ...          ...            ...         ...              ...       ...
# 2918  2007-04-01     2007-04-01  2007-05-21            sable     short
# 2919  2005-04-01     2004-04-01  2007-07-23            white    medium
# 2925  2006-06-01     2006-06-01  2006-11-29              red     short
# 2928  2007-01-15     2007-01-15  2007-03-17          striped    medium
# 2932  2003-12-25     2003-12-25  2006-03-22     yellow-brown     short
#
#         size neutered housebroken likes_people likes_children get_along_males  \
# 1      small       no         NaN          yes            yes             yes
# 6      small       no         NaN          yes            yes             yes
# 9      small       no         NaN          yes            yes             yes
# 13     small       no         NaN          yes            yes             yes
# 14    medium      yes         NaN          yes            yes              no
# ...      ...      ...         ...          ...            ...             ...
# 2918  medium      yes         NaN          yes            yes             yes
# 2919   large      yes         NaN          yes            yes             yes
# 2925  medium      yes         NaN          yes            yes             yes
# 2928  medium      NaN         NaN          yes            yes             yes
# 2932  medium       no          no          yes            yes              no
#
#      get_along_females get_along_cats               keep_in
# 1                  yes            yes                   NaN
# 6                  yes            yes                   NaN
# 9                  yes            yes                  flat
# 13                 yes            yes                  flat
# 14                  no             no                   NaN
# ...                ...            ...                   ...
# 2918               yes            NaN                   NaN
# 2919               yes            NaN                garden
# 2925               yes             no  both flat and garden
# 2928               yes            NaN  both flat and garden
# 2932               yes             no                garden
#
# [1121 rows x 19 columns]

# %%
cats_female = dogs[(dogs.get_along_females == 'yes') | (dogs.get_along_cats == 'yes')]
cats_female
# Out:
#         ID               name    age     sex                           breed  \
# 1      533     Frida És Ricsi   0.17  female                     Unknown Mix
# 6      534     Ricsi És Frida   0.17    male                     Unknown Mix
# 9     1801   Újhartyáni Mazsi   0.17  female                     Unknown Mix
# 13    1800  Újhartyáni Frenki   0.17    male                     Unknown Mix
# 16    1802    Újhartyáni Bori   0.17  female                     Unknown Mix
# ...    ...                ...    ...     ...                             ...
# 2925   427               Yuki  13.75    male         German Shepherd Dog Mix
# 2928   110             Kavics  13.75    male                        Pumi Mix
# 2931   362             Tündér  14.75  female          Labrador Retriever Mix
# 2932   118              Fodri  16.92    male                     Unknown Mix
# 2936   248             Kedves  16.08    male  German Shepherd Dog, Hound Mix
#
#      date_found adoptable_from      posted            color    coat    size  \
# 1    2019-12-01     2019-12-01  2019-12-09  black and white   short   small
# 6    2019-12-01     2019-12-01  2019-12-09            brown   short   small
# 9    2019-12-10     2019-12-10  2019-12-11  brown and white   short   small
# 13   2019-12-10     2019-12-10  2019-12-11         tricolor   short   small
# 16   2019-12-10     2019-12-10  2019-12-11         tricolor   short   small
# ...         ...            ...         ...              ...     ...     ...
# 2925 2006-06-01     2006-06-01  2006-11-29              red   short  medium
# 2928 2007-01-15     2007-01-15  2007-03-17          striped  medium  medium
# 2931 2006-05-01     2006-05-01  2006-06-28          apricot  medium  medium
# 2932 2003-12-25     2003-12-25  2006-03-22     yellow-brown   short  medium
# 2936 2005-04-02     2005-04-02  2005-06-30            sable   short  medium
#
#      neutered housebroken likes_people likes_children get_along_males  \
# 1          no         NaN          yes            yes             yes
# 6          no         NaN          yes            yes             yes
# 9          no         NaN          yes            yes             yes
# 13         no         NaN          yes            yes             yes
# 16         no         NaN          yes            yes             yes
# ...       ...         ...          ...            ...             ...
# 2925      yes         NaN          yes            yes             yes
# 2928      NaN         NaN          yes            yes             yes
# 2931      yes         NaN          NaN            yes             yes
# 2932       no          no          yes            yes              no
# 2936      yes         NaN          yes            NaN             yes
#
#      get_along_females get_along_cats               keep_in
# 1                  yes            yes                   NaN
# 6                  yes            yes                   NaN
# 9                  yes            yes                  flat
# 13                 yes            yes                  flat
# 16                 yes            yes                  flat
# ...                ...            ...                   ...
# 2925               yes             no  both flat and garden
# 2928               yes            NaN  both flat and garden
# 2931               yes            NaN  both flat and garden
# 2932               yes             no                garden
# 2936               yes            NaN  both flat and garden
#
# [1622 rows x 19 columns]

# %%
suitable = dogs[(dogs.neutered == 'yes') & (dogs.age >= 4)]
suitable
# Out:
#          ID               name    age     sex  \
# 5     23801               Alex   4.25    male
# 20    23788               Sába   7.58  female
# 41     1048     Velencei Fiffi   9.25  female
# 46     2154              Kormi   6.50    male
# 48     1049  Velencei Shyne On   8.42  female
# ...     ...                ...    ...     ...
# 2925    427               Yuki  13.75    male
# 2930    389              Pötyi  14.25  female
# 2931    362             Tündér  14.75  female
# 2933    262              Csibi  17.33  female
# 2936    248             Kedves  16.08    male
#
#                                    dog_breed  date_found date_adoptable  \
# 5                                Unknown Mix  2019-12-09     2019-12-24
# 20                                    Kuvasz  2019-12-01     2019-12-16
# 41                              Afghan Hound  2019-12-01     2019-12-04
# 46                               Unknown Mix  2019-10-07     2019-10-07
# 48                          American Bulldog  2019-12-01     2019-12-04
# ...                                      ...         ...            ...
# 2925                 German Shepherd Dog Mix  2006-06-01     2006-06-01
# 2930  German Pointer, Greyhound, Pointer Mix  2006-08-01     2006-08-01
# 2931                  Labrador Retriever Mix  2006-05-01     2006-05-01
# 2933               Staffordshire Terrier Mix  2004-08-27     2004-08-27
# 2936          German Shepherd Dog, Hound Mix  2005-04-02     2005-04-02
#
#      date_posted            color coat_type    size neutered housebroken  \
# 5     2019-12-09     yellow-brown     short   small      yes         NaN
# 20    2019-12-08            white    medium   large      yes         NaN
# 41    2019-12-03            brown      long  medium      yes         yes
# 46    2019-12-05            black     short  medium      yes         NaN
# 48    2019-12-03          striped     short  medium      yes         yes
# ...          ...              ...       ...     ...      ...         ...
# 2925  2006-11-29              red     short  medium      yes         NaN
# 2930  2006-08-20  black and white     short  medium      yes         NaN
# 2931  2006-06-28          apricot    medium  medium      yes         NaN
# 2933  2005-07-08          striped     short   large      yes         NaN
# 2936  2005-06-30            sable     short  medium      yes         NaN
#
#      likes_people likes_children get_along_males get_along_females  \
# 5             NaN            NaN             NaN               NaN
# 20            NaN            NaN             NaN               NaN
# 41            yes            NaN             NaN               NaN
# 46            NaN            NaN             NaN               NaN
# 48            yes            NaN             NaN               NaN
# ...           ...            ...             ...               ...
# 2925          yes            yes             yes               yes
# 2930          NaN            NaN             NaN               NaN
# 2931          NaN            yes             yes               yes
# 2933          NaN            NaN             NaN               NaN
# 2936          yes            NaN             yes               yes
#
#      get_along_cats               keep_in
# 5               NaN                   NaN
# 20              NaN                   NaN
# 41              NaN                  flat
# 46              NaN                   NaN
# 48              NaN  both flat and garden
# ...             ...                   ...
# 2925             no  both flat and garden
# 2930            NaN  both flat and garden
# 2931            NaN  both flat and garden
# 2933            NaN                   NaN
# 2936            NaN  both flat and garden
#
# [953 rows x 19 columns]

# %%
breed = dogs[(dogs.dog_breed.isin(['Staffordshire Terrier Mix', 'Labrador Retriever Mix', 'German Shepherd Dog Mix']))]
breed
# Out:
#          ID         name    age     sex                  dog_breed  \
# 26     4486        Cotta   0.15  female  Staffordshire Terrier Mix
# 27     4488      Kehlani   0.42  female    German Shepherd Dog Mix
# 34     4485        Panna   0.15  female  Staffordshire Terrier Mix
# 62     1791  Dabasi Bors   1.00    male  Staffordshire Terrier Mix
# 86    23754          NaN   1.00    male  Staffordshire Terrier Mix
# ...     ...          ...    ...     ...                        ...
# 2917     14        Kormi  17.67    male    German Shepherd Dog Mix
# 2918      6         Fifi  13.67  female    German Shepherd Dog Mix
# 2925    427         Yuki  13.75    male    German Shepherd Dog Mix
# 2931    362       Tündér  14.75  female     Labrador Retriever Mix
# 2933    262        Csibi  17.33  female  Staffordshire Terrier Mix
#
#       date_found date_adoptable date_posted            color coat_type  \
# 26    2019-12-01     2019-12-01  2019-12-07  brown and white     short
# 27    2019-12-01     2019-12-01  2019-12-07  black and brown     short
# 34    2019-12-01     2019-12-01  2019-12-07          striped     short
# 62    2019-11-28     2019-11-28  2019-11-28            brown     short
# 86    2019-11-25     2019-12-10  2019-11-25  black and white     short
# ...          ...            ...         ...              ...       ...
# 2917  2003-04-01     2004-04-01  2007-07-23            black     short
# 2918  2007-04-01     2007-04-01  2007-05-21            sable     short
# 2925  2006-06-01     2006-06-01  2006-11-29              red     short
# 2931  2006-05-01     2006-05-01  2006-06-28          apricot    medium
# 2933  2004-08-27     2004-08-27  2005-07-08          striped     short
#
#         size neutered housebroken likes_people likes_children get_along_males  \
# 26    medium      NaN         NaN          yes            NaN             yes
# 27    medium      NaN         NaN          yes            NaN             NaN
# 34    medium      NaN         NaN          yes            NaN             yes
# 62    medium       no         NaN          yes            yes             yes
# 86    medium      NaN         NaN          NaN            NaN             NaN
# ...      ...      ...         ...          ...            ...             ...
# 2917  medium       no         NaN          yes            yes             yes
# 2918  medium      yes         NaN          yes            yes             yes
# 2925  medium      yes         NaN          yes            yes             yes
# 2931  medium      yes         NaN          NaN            yes             yes
# 2933   large      yes         NaN          NaN            NaN             NaN
#
#      get_along_females get_along_cats               keep_in
# 26                 yes            NaN  both flat and garden
# 27                 NaN            NaN  both flat and garden
# 34                 yes            NaN  both flat and garden
# 62                 yes            NaN  both flat and garden
# 86                 NaN            NaN                   NaN
# ...                ...            ...                   ...
# 2917               yes            NaN                garden
# 2918               yes            NaN                   NaN
# 2925               yes             no  both flat and garden
# 2931               yes            NaN  both flat and garden
# 2933               NaN            NaN                   NaN
#
# [335 rows x 19 columns]

# %%
dogs[(dogs.dog_breed.isin(['Staffordshire Terrier Mix', 'Labrador Retriever Mix', 'German Shepherd Dog Mix']))].reset_index()
# Out:
#      index     ID         name    age     sex                  dog_breed  \
# 0       26   4486        Cotta   0.15  female  Staffordshire Terrier Mix
# 1       27   4488      Kehlani   0.42  female    German Shepherd Dog Mix
# 2       34   4485        Panna   0.15  female  Staffordshire Terrier Mix
# 3       62   1791  Dabasi Bors   1.00    male  Staffordshire Terrier Mix
# 4       86  23754          NaN   1.00    male  Staffordshire Terrier Mix
# ..     ...    ...          ...    ...     ...                        ...
# 330   2917     14        Kormi  17.67    male    German Shepherd Dog Mix
# 331   2918      6         Fifi  13.67  female    German Shepherd Dog Mix
# 332   2925    427         Yuki  13.75    male    German Shepherd Dog Mix
# 333   2931    362       Tündér  14.75  female     Labrador Retriever Mix
# 334   2933    262        Csibi  17.33  female  Staffordshire Terrier Mix
#
#      date_found date_adoptable date_posted            color coat_type    size  \
# 0    2019-12-01     2019-12-01  2019-12-07  brown and white     short  medium
# 1    2019-12-01     2019-12-01  2019-12-07  black and brown     short  medium
# 2    2019-12-01     2019-12-01  2019-12-07          striped     short  medium
# 3    2019-11-28     2019-11-28  2019-11-28            brown     short  medium
# 4    2019-11-25     2019-12-10  2019-11-25  black and white     short  medium
# ..          ...            ...         ...              ...       ...     ...
# 330  2003-04-01     2004-04-01  2007-07-23            black     short  medium
# 331  2007-04-01     2007-04-01  2007-05-21            sable     short  medium
# 332  2006-06-01     2006-06-01  2006-11-29              red     short  medium
# 333  2006-05-01     2006-05-01  2006-06-28          apricot    medium  medium
# 334  2004-08-27     2004-08-27  2005-07-08          striped     short   large
#
#     neutered housebroken likes_people likes_children get_along_males  \
# 0        NaN         NaN          yes            NaN             yes
# 1        NaN         NaN          yes            NaN             NaN
# 2        NaN         NaN          yes            NaN             yes
# 3         no         NaN          yes            yes             yes
# 4        NaN         NaN          NaN            NaN             NaN
# ..       ...         ...          ...            ...             ...
# 330       no         NaN          yes            yes             yes
# 331      yes         NaN          yes            yes             yes
# 332      yes         NaN          yes            yes             yes
# 333      yes         NaN          NaN            yes             yes
# 334      yes         NaN          NaN            NaN             NaN
#
#     get_along_females get_along_cats               keep_in
# 0                 yes            NaN  both flat and garden
# 1                 NaN            NaN  both flat and garden
# 2                 yes            NaN  both flat and garden
# 3                 yes            NaN  both flat and garden
# 4                 NaN            NaN                   NaN
# ..                ...            ...                   ...
# 330               yes            NaN                garden
# 331               yes            NaN                   NaN
# 332               yes             no  both flat and garden
# 333               yes            NaN  both flat and garden
# 334               NaN            NaN                   NaN
#
# [335 rows x 20 columns]

# %%
neutered_known = dogs.loc[dogs.neutered.notnull()]
neutered_known
# Out:
#          ID            name    age     sex                       dog_breed  \
# 0     23807            Gida   0.25  female                     Unknown Mix
# 1       533  Frida És Ricsi   0.17  female                     Unknown Mix
# 2     23793             NaN   4.00    male                     Unknown Mix
# 3     23795             NaN   1.00    male                     Unknown Mix
# 4     23806             Amy   2.00  female              French Bulldog Mix
# ...     ...             ...    ...     ...                             ...
# 2932    118           Fodri  16.92    male                     Unknown Mix
# 2933    262           Csibi  17.33  female       Staffordshire Terrier Mix
# 2934      4          Konrád  18.17    male                     Unknown Mix
# 2935    141           Kölni  17.17    male                     Unknown Mix
# 2936    248          Kedves  16.08    male  German Shepherd Dog, Hound Mix
#
#       date_found date_adoptable date_posted            color coat_type  \
# 0     2019-12-10     2019-12-11  2019-12-11              red     short
# 1     2019-12-01     2019-12-01  2019-12-09  black and white     short
# 2     2019-12-08     2019-12-23  2019-12-08      saddle back     short
# 3     2019-12-08     2019-12-23  2019-12-08     yellow-brown    medium
# 4     2019-12-10     2019-12-11  2019-12-11            black     short
# ...          ...            ...         ...              ...       ...
# 2932  2003-12-25     2003-12-25  2006-03-22     yellow-brown     short
# 2933  2004-08-27     2004-08-27  2005-07-08          striped     short
# 2934  2005-09-21     2005-09-21  2005-10-26            black     short
# 2935  2004-11-27     2004-11-27  2005-05-02  black and brown    medium
# 2936  2005-04-02     2005-04-02  2005-06-30            sable     short
#
#         size neutered housebroken likes_people likes_children get_along_males  \
# 0      small       no         NaN          NaN            NaN             NaN
# 1      small       no         NaN          yes            yes             yes
# 2     medium       no         NaN          NaN            NaN             NaN
# 3     medium       no         NaN          NaN            NaN             NaN
# 4      small       no         NaN          NaN            NaN             NaN
# ...      ...      ...         ...          ...            ...             ...
# 2932  medium       no          no          yes            yes              no
# 2933   large      yes         NaN          NaN            NaN             NaN
# 2934  medium       no         NaN          NaN            NaN             NaN
# 2935  medium       no         NaN          NaN            NaN             NaN
# 2936  medium      yes         NaN          yes            NaN             yes
#
#      get_along_females get_along_cats               keep_in
# 0                  NaN            NaN                   NaN
# 1                  yes            yes                   NaN
# 2                  NaN            NaN                   NaN
# 3                  NaN            NaN                   NaN
# 4                  NaN            NaN                   NaN
# ...                ...            ...                   ...
# 2932               yes             no                garden
# 2933               NaN            NaN                   NaN
# 2934               NaN            NaN                   NaN
# 2935               NaN            NaN                   NaN
# 2936               yes            NaN  both flat and garden
#
# [1852 rows x 19 columns]

# %%
neutered_unknown = dogs.loc[dogs.neutered.isnull()]
neutered_unknown
# Out:
#         ID     name    age     sex                           dog_breed  \
# 21    4492     Döme   1.00    male                         Unknown Mix
# 22    4484  Jocelyn   0.17  female                         Unknown Mix
# 24    4487   Katica   0.58  female                         Unknown Mix
# 25    4491  Bethany   5.00  female                Chinese Shar-Pei Mix
# 26    4486    Cotta   0.15  female           Staffordshire Terrier Mix
# ...    ...      ...    ...     ...                                 ...
# 2910    25    Pongo  14.67    male               Beagle, Dachshund Mix
# 2912    21   Maggie  14.67  female  German Dog, Labrador Retriever Mix
# 2913     2    Diego  13.67    male                       Dachshund Mix
# 2926   109     Kari  13.33  female         German Pointer, Pointer Mix
# 2928   110   Kavics  13.75    male                            Pumi Mix
#
#       date_found date_adoptable date_posted            color coat_type  \
# 21    2019-11-25     2019-11-25  2019-12-07            black    medium
# 22    2019-11-27     2019-11-27  2019-12-07          apricot     short
# 24    2019-12-03     2019-12-03  2019-12-07            black     short
# 25    2019-11-28     2019-11-28  2019-12-07  black and brown     short
# 26    2019-12-01     2019-12-01  2019-12-07  brown and white     short
# ...          ...            ...         ...              ...       ...
# 2910  2006-04-01     2007-05-01  2007-07-23         tricolor     short
# 2912  2006-07-01     2007-05-01  2007-07-23            black     short
# 2913  2007-04-01     2007-04-01  2007-05-21              red     short
# 2926  2007-01-15     2007-01-15  2007-03-16  black and white     short
# 2928  2007-01-15     2007-01-15  2007-03-17          striped    medium
#
#         size neutered housebroken likes_people likes_children get_along_males  \
# 21    medium      NaN         NaN          yes            NaN             NaN
# 22     small      NaN         NaN          yes            NaN             yes
# 24     small      NaN         NaN          yes            NaN             NaN
# 25    medium      NaN         NaN          yes            NaN             NaN
# 26    medium      NaN         NaN          yes            NaN             yes
# ...      ...      ...         ...          ...            ...             ...
# 2910   small      NaN         NaN          yes            yes             yes
# 2912   large      NaN         NaN          yes            yes             yes
# 2913   small      NaN         yes          yes            yes             yes
# 2926  medium      NaN         NaN          NaN            NaN             NaN
# 2928  medium      NaN         NaN          yes            yes             yes
#
#      get_along_females get_along_cats               keep_in
# 21                 NaN            yes  both flat and garden
# 22                 yes            NaN  both flat and garden
# 24                 NaN            NaN  both flat and garden
# 25                 NaN            NaN  both flat and garden
# 26                 yes            NaN  both flat and garden
# ...                ...            ...                   ...
# 2910               yes            NaN  both flat and garden
# 2912               yes            NaN  both flat and garden
# 2913               yes            NaN  both flat and garden
# 2926               NaN            NaN                   NaN
# 2928               yes            NaN  both flat and garden
#
# [1085 rows x 19 columns]

# %%
dogs.fillna("not available")
# Out:
#          ID            name    age     sex                       dog_breed  \
# 0     23807            Gida   0.25  female                     Unknown Mix
# 1       533  Frida És Ricsi   0.17  female                     Unknown Mix
# 2     23793   not available   4.00    male                     Unknown Mix
# 3     23795   not available   1.00    male                     Unknown Mix
# 4     23806             Amy   2.00  female              French Bulldog Mix
# ...     ...             ...    ...     ...                             ...
# 2932    118           Fodri  16.92    male                     Unknown Mix
# 2933    262           Csibi  17.33  female       Staffordshire Terrier Mix
# 2934      4          Konrád  18.17    male                     Unknown Mix
# 2935    141           Kölni  17.17    male                     Unknown Mix
# 2936    248          Kedves  16.08    male  German Shepherd Dog, Hound Mix
#
#      date_found date_adoptable date_posted            color coat_type    size  \
# 0    2019-12-10     2019-12-11  2019-12-11              red     short   small
# 1    2019-12-01     2019-12-01  2019-12-09  black and white     short   small
# 2    2019-12-08     2019-12-23  2019-12-08      saddle back     short  medium
# 3    2019-12-08     2019-12-23  2019-12-08     yellow-brown    medium  medium
# 4    2019-12-10     2019-12-11  2019-12-11            black     short   small
# ...         ...            ...         ...              ...       ...     ...
# 2932 2003-12-25     2003-12-25  2006-03-22     yellow-brown     short  medium
# 2933 2004-08-27     2004-08-27  2005-07-08          striped     short   large
# 2934 2005-09-21     2005-09-21  2005-10-26            black     short  medium
# 2935 2004-11-27     2004-11-27  2005-05-02  black and brown    medium  medium
# 2936 2005-04-02     2005-04-02  2005-06-30            sable     short  medium
#
#      neutered    housebroken   likes_people likes_children get_along_males  \
# 0          no  not available  not available  not available   not available
# 1          no  not available            yes            yes             yes
# 2          no  not available  not available  not available   not available
# 3          no  not available  not available  not available   not available
# 4          no  not available  not available  not available   not available
# ...       ...            ...            ...            ...             ...
# 2932       no             no            yes            yes              no
# 2933      yes  not available  not available  not available   not available
# 2934       no  not available  not available  not available   not available
# 2935       no  not available  not available  not available   not available
# 2936      yes  not available            yes  not available             yes
#
#      get_along_females get_along_cats               keep_in
# 0        not available  not available         not available
# 1                  yes            yes         not available
# 2        not available  not available         not available
# 3        not available  not available         not available
# 4        not available  not available         not available
# ...                ...            ...                   ...
# 2932               yes             no                garden
# 2933     not available  not available         not available
# 2934     not available  not available         not available
# 2935     not available  not available         not available
# 2936               yes  not available  both flat and garden
#
# [2937 rows x 19 columns]
